# %%
import tensorflow as tf
from ISR.models.faceGenerator import FaceGenerator
from ISR.models.discriminator import Discriminator
from ISR.models import RRDN

# %%
rrdn = RRDN(arch_params={'C':4, 'D':3, 'G':64, 'G0':64,'T':10,'x':1}, patch_size=80)
discr = Discriminator(patch_size=80, kernel_size=3)
discr.model.summary()
# Out:
# Model: "discriminator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 80, 80, 3)]       0
# _________________________________________________________________
# Conv_1 (Conv2D)              (None, 80, 80, 64)        1792
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 80, 80, 64)        0
# _________________________________________________________________
# Conv_2 (Conv2D)              (None, 40, 40, 64)        36928
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 40, 40, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 40, 40, 64)        256
# _________________________________________________________________
# Conv_3 (Conv2D)              (None, 40, 40, 128)       73856
# ...

# %%
gen = FaceGenerator(patch_size=224)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 14, 14, 3) for input Tensor("input_5:0", shape=(None, 14, 14, 3), dtype=float32), but it was called on an input with incompatible shape (None, 224, 224, 3).

# %%
gen.model.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-95d5423a18cc> in <module>
# ----> 1 gen.model.summary()
#
# AttributeError: 'Tensor' object has no attribute 'summary'

# %%
gen.encoder.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 224, 224, 9)  0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# ...

# %%
gen.decoder.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_8 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          131328      input_8[0][0]
# __________________________________________________________________________________________________
# instance_normalization_4 (Insta (None, 256)          2           dense[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 256)          0           instance_normalization_4[0][0]
# __________________________________________________________________________________________________
# ...
