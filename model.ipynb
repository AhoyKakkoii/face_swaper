# %%
from ISR.models.encoder import Encoder

# %%
encoder = Encoder(arch_params={'C':4, 'D':3, 'G':64, 'G0':64,'T':3,'x':1}, patch_size=80)
encoder.model.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# LR_input (InputLayer)           [(None, 80, 80, 3)]  0
# __________________________________________________________________________________________________
# Pre_blocks_conv (Conv2D)        (None, 80, 80, 64)   1792        LR_input[0][0]
# __________________________________________________________________________________________________
# F_1_1_1 (Conv2D)                (None, 80, 80, 64)   36928       Pre_blocks_conv[0][0]
# __________________________________________________________________________________________________
# F_1_1_1_Relu (Activation)       (None, 80, 80, 64)   0           F_1_1_1[0][0]
# __________________________________________________________________________________________________
# ...
